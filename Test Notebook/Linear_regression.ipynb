# %%
import pandas as pd 
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\amitr\OneDrive\Desktop\moduler\ML_live_class\Test Notebook\Linear_regression.ipynb Cell 1' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/amitr/OneDrive/Desktop/moduler/ML_live_class/Test%20Notebook/Linear_regression.ipynb#ch0000000?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/amitr/OneDrive/Desktop/moduler/ML_live_class/Test%20Notebook/Linear_regression.ipynb#ch0000000?line=2'>3</a> import pickle
# ----> <a href='vscode-notebook-cell:/c%3A/Users/amitr/OneDrive/Desktop/moduler/ML_live_class/Test%20Notebook/Linear_regression.ipynb#ch0000000?line=3'>4</a> import seaborn as sns
# ...
